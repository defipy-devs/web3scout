# %%
import json
import time
from web3scout import *

# %%
abi = ABILoad(Platform.SUSHI, JSONContract.UniswapV2Pair)

# %% [markdown]
# ### (1) Extract Mint Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 100

# %%
dict_events = rEvents.apply(EventType.MINT, start_block=start_block, end_block=last_block)
# Out:
# mint at block:61,738,751 tx:0xe8c04439f59a8e00c9a8fa5480ac5126bbc9ea50311c04820c7508c403c4b4b6
# mint at block:61,738,764 tx:0xc281457635f41824a1162c9c01bbdfb4336dc4f91c4ac6e05a9f2ab22bae8b44
# mint at block:61,738,764 tx:0xc281457635f41824a1162c9c01bbdfb4336dc4f91c4ac6e05a9f2ab22bae8b44
# mint at block:61,738,765 tx:0x246651daa3921d3112d8acebb29dc5154e6d84824fd00d1ecb15adef32345438
# mint at block:61,738,765 tx:0x246651daa3921d3112d8acebb29dc5154e6d84824fd00d1ecb15adef32345438
# mint at block:61,738,767 tx:0x79af7f3654af7b766cebff754eaf4a270acc077987a389e3e12351ff5692d544
# mint at block:61,738,779 tx:0x845a9a07903f87c5eebe402ac306d554fcda07909c3808c98b5885ac59995c8f
# mint at block:61,738,785 tx:0xb75cbcb71733e99dde4e3051cd61349346e4a92511e8aa7ae601d189f2df2b9c
# mint at block:61,738,785 tx:0xb75cbcb71733e99dde4e3051cd61349346e4a92511e8aa7ae601d189f2df2b9c
# mint at block:61,738,793 tx:0x8a21ad99a7cdbbaf6153bb44a694b556fa4530f0ddfbea0868da8449d421108f
# mint at block:61,738,806 tx:0x587b308f70d0f24b7da220f3d87e418e476d10fbf64a2e3e784dc59d1bfa9568
# mint at block:61,738,806 tx:0x587b308f70d0f24b7da220f3d87e418e476d10fbf64a2e3e784dc59d1bfa9568
# mint at block:61,738,808 tx:0x1879a965cee826d32f940ec57021d6a58e08099fdb0697dc7f6ff3708b4fbdac
# mint at block:61,738,808 tx:0x1879a965cee826d32f940ec57021d6a58e08099fdb0697dc7f6ff3708b4fbdac
# mint at block:61,738,808 tx:0x1879a965cee826d32f940ec57021d6a58e08099fdb0697dc7f6ff3708b4fbdac
# mint at block:61,738,815 tx:0x5c38e3b1879846bbb4d3d344921a67dde3dddc7c61d67e5511a72b5be86ff99d
# mint at block:61,738,815 tx:0x5c38e3b1879846bbb4d3d344921a67dde3dddc7c61d67e5511a72b5be86ff99d
# mint at block:61,738,817 tx:0x25bddcd59486ee161619e47be558a4a57c878c62fa96da55643fb282d72a43f5
# mint at block:61,738,817 tx:0x25bddcd59486ee161619e47be558a4a57c878c62fa96da55643fb282d72a43f5
# mint at block:61,738,817 tx:0x25bddcd59486ee161619e47be558a4a57c878c62fa96da55643fb282d72a43f5
# mint at block:61,738,817 tx:0x25bddcd59486ee161619e47be558a4a57c878c62fa96da55643fb282d72a43f5
# mint at block:61,738,823 tx:0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40ffffa8f7e5a87b5344b5
# mint at block:61,738,823 tx:0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40ffffa8f7e5a87b5344b5
# mint at block:61,738,823 tx:0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40ffffa8f7e5a87b5344b5
# mint at block:61,738,823 tx:0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40ffffa8f7e5a87b5344b5
# mint at block:61,738,828 tx:0x1a1026687bdcfb92d32391c70483e756438ccb1de40b38c4ff6d140680a3b42f
# mint at block:61,738,832 tx:0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd80746f3f5ce9978bda26
# mint at block:61,738,832 tx:0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd80746f3f5ce9978bda26
# mint at block:61,738,832 tx:0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd80746f3f5ce9978bda26
# mint at block:61,738,835 tx:0x96d286e045c8ec7087ce734ad6ae049cabf5af91529b59da2f8546e7d4a48f89
# mint at block:61,738,835 tx:0x96d286e045c8ec7087ce734ad6ae049cabf5af91529b59da2f8546e7d4a48f89
# mint at block:61,738,849 tx:0xe7c69e9138b3a508bf0c6e5cee427d95b70009f473a8698a895ee56c24e62e63
# mint at block:61,738,849 tx:0x8a61b5ed5cd28a04f400288149b2bdec0e8b9a2815a8ce6dcd8d8847711e263e
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type platform  \
# 0   polygon  uniswapv2pair  mint    sushi
# 1   polygon  uniswapv2pair  mint    sushi
# 2   polygon  uniswapv2pair  mint    sushi
# 3   polygon  uniswapv2pair  mint    sushi
# 4   polygon  uniswapv2pair  mint    sushi
# 5   polygon  uniswapv2pair  mint    sushi
# 6   polygon  uniswapv2pair  mint    sushi
# 7   polygon  uniswapv2pair  mint    sushi
# 8   polygon  uniswapv2pair  mint    sushi
# 9   polygon  uniswapv2pair  mint    sushi
# 10  polygon  uniswapv2pair  mint    sushi
# 11  polygon  uniswapv2pair  mint    sushi
# 12  polygon  uniswapv2pair  mint    sushi
# 13  polygon  uniswapv2pair  mint    sushi
# 14  polygon  uniswapv2pair  mint    sushi
# 15  polygon  uniswapv2pair  mint    sushi
# 16  polygon  uniswapv2pair  mint    sushi
# 17  polygon  uniswapv2pair  mint    sushi
# 18  polygon  uniswapv2pair  mint    sushi
# 19  polygon  uniswapv2pair  mint    sushi
# 20  polygon  uniswapv2pair  mint    sushi
# 21  polygon  uniswapv2pair  mint    sushi
# 22  polygon  uniswapv2pair  mint    sushi
# 23  polygon  uniswapv2pair  mint    sushi
# 24  polygon  uniswapv2pair  mint    sushi
# 25  polygon  uniswapv2pair  mint    sushi
# 26  polygon  uniswapv2pair  mint    sushi
# 27  polygon  uniswapv2pair  mint    sushi
# 28  polygon  uniswapv2pair  mint    sushi
# 29  polygon  uniswapv2pair  mint    sushi
# 30  polygon  uniswapv2pair  mint    sushi
# 31  polygon  uniswapv2pair  mint    sushi
# 32  polygon  uniswapv2pair  mint    sushi
#
#                                        address  \
# 0   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 1   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 2   0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 3   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 4   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 5   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 6   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 7   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 8   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 9   0x60d55f02a771d515e077c9c2403a1ef324885cec
# 10  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 11  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 12  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 13  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 14  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 15  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 16  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 17  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 18  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 19  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 20  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 21  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 22  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 23  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 24  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 25  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 26  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 27  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 28  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 29  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 30  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 31  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 32  0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0xe8c04439f59a8e00c9a8fa5480ac5126bbc9ea50311c...  61738751  1726153885
# 1   0xc281457635f41824a1162c9c01bbdfb4336dc4f91c4a...  61738764  1726153913
# 2   0xc281457635f41824a1162c9c01bbdfb4336dc4f91c4a...  61738764  1726153913
# 3   0x246651daa3921d3112d8acebb29dc5154e6d84824fd0...  61738765  1726153915
# 4   0x246651daa3921d3112d8acebb29dc5154e6d84824fd0...  61738765  1726153915
# 5   0x79af7f3654af7b766cebff754eaf4a270acc077987a3...  61738767  1726153919
# 6   0x845a9a07903f87c5eebe402ac306d554fcda07909c38...  61738779  1726153945
# 7   0xb75cbcb71733e99dde4e3051cd61349346e4a92511e8...  61738785  1726153959
# 8   0xb75cbcb71733e99dde4e3051cd61349346e4a92511e8...  61738785  1726153959
# 9   0x8a21ad99a7cdbbaf6153bb44a694b556fa4530f0ddfb...  61738793  1726153975
# 10  0x587b308f70d0f24b7da220f3d87e418e476d10fbf64a...  61738806  1726154003
# 11  0x587b308f70d0f24b7da220f3d87e418e476d10fbf64a...  61738806  1726154003
# 12  0x1879a965cee826d32f940ec57021d6a58e08099fdb06...  61738808  1726154007
# 13  0x1879a965cee826d32f940ec57021d6a58e08099fdb06...  61738808  1726154007
# 14  0x1879a965cee826d32f940ec57021d6a58e08099fdb06...  61738808  1726154007
# 15  0x5c38e3b1879846bbb4d3d344921a67dde3dddc7c61d6...  61738815  1726154021
# 16  0x5c38e3b1879846bbb4d3d344921a67dde3dddc7c61d6...  61738815  1726154021
# 17  0x25bddcd59486ee161619e47be558a4a57c878c62fa96...  61738817  1726154027
# 18  0x25bddcd59486ee161619e47be558a4a57c878c62fa96...  61738817  1726154027
# 19  0x25bddcd59486ee161619e47be558a4a57c878c62fa96...  61738817  1726154027
# 20  0x25bddcd59486ee161619e47be558a4a57c878c62fa96...  61738817  1726154027
# 21  0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40...  61738823  1726154039
# 22  0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40...  61738823  1726154039
# 23  0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40...  61738823  1726154039
# 24  0x628f4be0ca37804824ae72c9c9ed9b4301762a4b6f40...  61738823  1726154039
# 25  0x1a1026687bdcfb92d32391c70483e756438ccb1de40b...  61738828  1726154049
# 26  0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd...  61738832  1726154059
# 27  0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd...  61738832  1726154059
# 28  0xf412ce369f88430c3ca5e6595cce42f25844b928e2dd...  61738832  1726154059
# 29  0x96d286e045c8ec7087ce734ad6ae049cabf5af91529b...  61738835  1726154065
# 30  0x96d286e045c8ec7087ce734ad6ae049cabf5af91529b...  61738835  1726154065
# 31  0xe7c69e9138b3a508bf0c6e5cee427d95b70009f473a8...  61738849  1726154095
# 32  0x8a61b5ed5cd28a04f400288149b2bdec0e8b9a2815a8...  61738849  1726154095
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 1   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 2   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 3   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 4   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 5   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 6   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 7   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 8   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 9   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 10  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 11  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 12  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 13  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 14  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 15  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 16  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 17  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 18  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 19  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 20  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 21  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 22  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 23  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 24  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 25  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 26  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 27  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 28  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 29  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 30  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 31  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 32  {'web3_type': <class 'web3._utils.datatypes.Mi...

# %% [markdown]
# ### (2) Extract Swap Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 3

# %%
dict_events = rEvents.apply(EventType.SWAP, start_block=start_block, end_block=last_block)
# Out:
# swap at block:61,738,852 tx:0xfb0cc41e9c337188e28572ee9754cb030118854c077733af051f2fe622ab8342
# swap at block:61,738,852 tx:0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5
# swap at block:61,738,852 tx:0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5
# swap at block:61,738,852 tx:0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5
# swap at block:61,738,852 tx:0x9862c0dfa1f49218ad0408d20fe919539ffa73cf744f803a35e8559b516ff3de
# swap at block:61,738,852 tx:0x55bb39067fab0c28bfcf8465a01a6c4cb1b9cd629ce40cc9b5d08e34e0cd952e
# swap at block:61,738,853 tx:0x281abfa4b40b32715fdf3e78d1a137fce708d6349211a989f79f52f176a7b12b
# swap at block:61,738,853 tx:0x281abfa4b40b32715fdf3e78d1a137fce708d6349211a989f79f52f176a7b12b
# swap at block:61,738,854 tx:0x4c68dc76e3f57e1e786a309206954eba0032268394349e28a3764ff23cb02f59
# swap at block:61,738,854 tx:0x4c68dc76e3f57e1e786a309206954eba0032268394349e28a3764ff23cb02f59
# swap at block:61,738,854 tx:0xb3070c2b52e9361a4a35a72270ab66a57b742d657cbd2d5c7681e1ab0778e653
# swap at block:61,738,855 tx:0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6
# swap at block:61,738,855 tx:0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6
# swap at block:61,738,855 tx:0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6
# swap at block:61,738,855 tx:0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type platform  \
# 0   polygon  uniswapv2pair  swap    sushi
# 1   polygon  uniswapv2pair  swap    sushi
# 2   polygon  uniswapv2pair  swap    sushi
# 3   polygon  uniswapv2pair  swap    sushi
# 4   polygon  uniswapv2pair  swap    sushi
# 5   polygon  uniswapv2pair  swap    sushi
# 6   polygon  uniswapv2pair  swap    sushi
# 7   polygon  uniswapv2pair  swap    sushi
# 8   polygon  uniswapv2pair  swap    sushi
# 9   polygon  uniswapv2pair  swap    sushi
# 10  polygon  uniswapv2pair  swap    sushi
# 11  polygon  uniswapv2pair  swap    sushi
# 12  polygon  uniswapv2pair  swap    sushi
# 13  polygon  uniswapv2pair  swap    sushi
# 14  polygon  uniswapv2pair  swap    sushi
#
#                                        address  \
# 0   0x2813d43463c374a680f235c428fb1d7f08de0b69
# 1   0x882df4b0fb50a229c3b4124eb18c759911485bfb
# 2   0x882df4b0fb50a229c3b4124eb18c759911485bfb
# 3   0x882df4b0fb50a229c3b4124eb18c759911485bfb
# 4   0x232eb60e4ea68a164988329e16305bcacccf2a97
# 5   0xa5cabfc725dfa129f618d527e93702d10412f039
# 6   0x2cc4a8f03983bdd1958717d3d4e5e30564989cf7
# 7   0x395ab6556774e613ec38a15e004c6d0367c00ca2
# 8   0xfc2fc983a411c4b1e238f7eb949308cf0218c750
# 9   0x1d608df1bcad4681f1b929110710eb936d7354e5
# 10  0xfe3a75416a889449f89f74ad7181892867a062fb
# 11  0x4a35582a710e1f4b2030a3f826da20bfb6703c09
# 12  0xf6422b997c7f54d1c6a6e103bcb1499eea0a7046
# 13  0xc2755915a85c6f6c1c0f3a86ac8c058f11caa9c9
# 14  0x6ff62bfb8c12109e8000935a6de54dad83a4f39f
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0xfb0cc41e9c337188e28572ee9754cb030118854c0777...  61738852  1726154101
# 1   0x464ed27b220c5ba9096815d6b494425344813a36cbeb...  61738852  1726154101
# 2   0x464ed27b220c5ba9096815d6b494425344813a36cbeb...  61738852  1726154101
# 3   0x464ed27b220c5ba9096815d6b494425344813a36cbeb...  61738852  1726154101
# 4   0x9862c0dfa1f49218ad0408d20fe919539ffa73cf744f...  61738852  1726154101
# 5   0x55bb39067fab0c28bfcf8465a01a6c4cb1b9cd629ce4...  61738852  1726154101
# 6   0x281abfa4b40b32715fdf3e78d1a137fce708d6349211...  61738853  1726154103
# 7   0x281abfa4b40b32715fdf3e78d1a137fce708d6349211...  61738853  1726154103
# 8   0x4c68dc76e3f57e1e786a309206954eba003226839434...  61738854  1726154105
# 9   0x4c68dc76e3f57e1e786a309206954eba003226839434...  61738854  1726154105
# 10  0xb3070c2b52e9361a4a35a72270ab66a57b742d657cbd...  61738854  1726154105
# 11  0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599...  61738855  1726154107
# 12  0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599...  61738855  1726154107
# 13  0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599...  61738855  1726154107
# 14  0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599...  61738855  1726154107
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 1   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 2   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 3   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 4   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 5   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 6   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 7   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 8   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 9   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 10  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 11  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 12  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 13  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 14  {'web3_type': <class 'web3._utils.datatypes.Sw...

# %%
dict_events
# Out:
# {0: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x2813d43463c374a680f235c428fb1d7f08de0b69',
#   'tx_hash': '0xfb0cc41e9c337188e28572ee9754cb030118854c077733af051f2fe622ab8342',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xB33bD56d4192E8E4e6a02e93Eabc732165199346',
#    'token1': '0xB33bD56d4192E8E4e6a02e93Eabc732165199346',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  1: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x882df4b0fb50a229c3b4124eb18c759911485bfb',
#   'tx_hash': '0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa5E0829CaCEd8fFDD4De3c43696c57F7D7A678ff',
#    'token1': '0xA304823C775d13fc851379C75e2b6f300E223234',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  2: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x882df4b0fb50a229c3b4124eb18c759911485bfb',
#   'tx_hash': '0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa5E0829CaCEd8fFDD4De3c43696c57F7D7A678ff',
#    'token1': '0xA304823C775d13fc851379C75e2b6f300E223234',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  3: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x882df4b0fb50a229c3b4124eb18c759911485bfb',
#   'tx_hash': '0x464ed27b220c5ba9096815d6b494425344813a36cbeb5bcbdb404f207874edc5',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa5E0829CaCEd8fFDD4De3c43696c57F7D7A678ff',
#    'token1': '0x2D50cA22167109b1Edc534fD487a4cBc43Cfe761',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  4: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x232eb60e4ea68a164988329e16305bcacccf2a97',
#   'tx_hash': '0x9862c0dfa1f49218ad0408d20fe919539ffa73cf744f803a35e8559b516ff3de',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xedf6066a2b290C185783862C7F4776A2C8077AD1',
#    'token1': '0x6B5aaF38F7907DfB6d09321bF98f237fC24b2Fb7',
#    'amount0In': 482017453205556035584,
#    'amount1Out': 11632797}},
#  5: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0xa5cabfc725dfa129f618d527e93702d10412f039',
#   'tx_hash': '0x55bb39067fab0c28bfcf8465a01a6c4cb1b9cd629ce40cc9b5d08e34e0cd952e',
#   'blk_num': 61738852,
#   'timestamp': 1726154101,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x8308a7D7655C2ae21632eD3dd6F55f509E7dfDb9',
#    'token1': '0x0303E4Fe3d5a3d4F225E7690F038786648657b2B',
#    'amount0In': 31722984,
#    'amount1Out': 2608259}},
#  6: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x2cc4a8f03983bdd1958717d3d4e5e30564989cf7',
#   'tx_hash': '0x281abfa4b40b32715fdf3e78d1a137fce708d6349211a989f79f52f176a7b12b',
#   'blk_num': 61738853,
#   'timestamp': 1726154103,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xd396e3b790F0fa79C80c69BD48127DB988A56bEb',
#    'token1': '0x395ab6556774E613ec38a15e004C6d0367C00Ca2',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  7: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x395ab6556774e613ec38a15e004c6d0367c00ca2',
#   'tx_hash': '0x281abfa4b40b32715fdf3e78d1a137fce708d6349211a989f79f52f176a7b12b',
#   'blk_num': 61738853,
#   'timestamp': 1726154103,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xd396e3b790F0fa79C80c69BD48127DB988A56bEb',
#    'token1': '0xd396e3b790F0fa79C80c69BD48127DB988A56bEb',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  8: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0xfc2fc983a411c4b1e238f7eb949308cf0218c750',
#   'tx_hash': '0x4c68dc76e3f57e1e786a309206954eba0032268394349e28a3764ff23cb02f59',
#   'blk_num': 61738854,
#   'timestamp': 1726154105,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x37af74b8096A6fd85bc4A36653a60B8D673BaEFc',
#    'token1': '0x3cf7A3399439e3C10E2ea7e01272B54A66A04BA6',
#    'amount0In': 1141808398638563,
#    'amount1Out': 219702}},
#  9: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x1d608df1bcad4681f1b929110710eb936d7354e5',
#   'tx_hash': '0x4c68dc76e3f57e1e786a309206954eba0032268394349e28a3764ff23cb02f59',
#   'blk_num': 61738854,
#   'timestamp': 1726154105,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x3cf7A3399439e3C10E2ea7e01272B54A66A04BA6',
#    'token1': '0x3cf7A3399439e3C10E2ea7e01272B54A66A04BA6',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  10: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0xfe3a75416a889449f89f74ad7181892867a062fb',
#   'tx_hash': '0xb3070c2b52e9361a4a35a72270ab66a57b742d657cbd2d5c7681e1ab0778e653',
#   'blk_num': 61738854,
#   'timestamp': 1726154105,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xd02667662e03EbC6bCD30ff89A737B18a30f7a70',
#    'token1': '0x94a060B018778b9eC377FE804d4381DB9f7d3883',
#    'amount0In': 88762245862569400,
#    'amount1Out': 6756890972386803268}},
#  11: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x4a35582a710e1f4b2030a3f826da20bfb6703c09',
#   'tx_hash': '0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6',
#   'blk_num': 61738855,
#   'timestamp': 1726154107,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa5E0829CaCEd8fFDD4De3c43696c57F7D7A678ff',
#    'token1': '0xF6422B997c7F54D1c6a6e103bcb1499EeA0a7046',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  12: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0xf6422b997c7f54d1c6a6e103bcb1499eea0a7046',
#   'tx_hash': '0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6',
#   'blk_num': 61738855,
#   'timestamp': 1726154107,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa5E0829CaCEd8fFDD4De3c43696c57F7D7A678ff',
#    'token1': '0xbb524eA093A4aEd3d013a5B14Dd16175B1AB3ad9',
#    'amount0In': 2962821169051691,
#    'amount1Out': 6887657}},
#  13: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0xc2755915a85c6f6c1c0f3a86ac8c058f11caa9c9',
#   'tx_hash': '0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6',
#   'blk_num': 61738855,
#   'timestamp': 1726154107,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x1b02dA8Cb0d097eB8D57A175b88c7D8b47997506',
#    'token1': '0x6FF62bfb8c12109E8000935A6De54daD83a4f39f',
#    'amount0In': 0,
#    'amount1Out': 0}},
#  14: {'chain': 'polygon',
#   'contract': 'uniswapv2pair',
#   'type': 'swap',
#   'platform': 'sushi',
#   'address': '0x6ff62bfb8c12109e8000935a6de54dad83a4f39f',
#   'tx_hash': '0x4e11e57b78905fdd3d5c43f99258e46d2172182ed599e5b461e392934def01b6',
#   'blk_num': 61738855,
#   'timestamp': 1726154107,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x1b02dA8Cb0d097eB8D57A175b88c7D8b47997506',
#    'token1': '0xbb524eA093A4aEd3d013a5B14Dd16175B1AB3ad9',
#    'amount0In': 2947462935003722,
#    'amount1Out': 6860841915097576255}}}

# %% [markdown]
# ### (3) Extract Burn Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 250

# %%
dict_events = rEvents.apply(EventType.BURN, start_block=start_block, end_block=last_block)
# Out:
# burn at block:61,738,703 tx:0xd792b359d27944799f422a0985907dfbec291f39af295638df1e34729e74b64e
# burn at block:61,738,853 tx:0x9800eaea6da5c83fde1fd918ea373478696dd0584e6f33f5e3ca6f795758979d
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#      chain       contract  type platform  \
# 0  polygon  uniswapv2pair  burn    sushi
# 1  polygon  uniswapv2pair  burn    sushi
#
#                                       address  \
# 0  0x882df4b0fb50a229c3b4124eb18c759911485bfb
# 1  0x71f7e275adaae332f9c2cf802e8a545d408e5c07
#
#                                              tx_hash   blk_num   timestamp  \
# 0  0xd792b359d27944799f422a0985907dfbec291f39af29...  61738703  1726153783
# 1  0x9800eaea6da5c83fde1fd918ea373478696dd0584e6f...  61738853  1726154103
#
#                                              details
# 0  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 1  {'web3_type': <class 'web3._utils.datatypes.Bu...

# %% [markdown]
# ### (4) Extract Sync Events (Price Oracle)

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 10

# %%
dict_events = rEvents.apply(EventType.SYNC, start_block=start_block, end_block=last_block)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dict_events = rEvents.apply(EventType.SYNC, start_block=start_block, end_block=last_block)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/web3scout/event/process/retrieve_events.py:32, in RetrieveEvents.apply(self, event_type, address, start_block, end_block)
#      30 for k, evt in enumerate(read_events):
#      31     key = evt["blockHash"] + evt["transactionHash"] + evt["logIndex"]
# ---> 32     record_event = event.record(evt, self.__abi)
#      34     dict_events[k] = record_event
#      35     if key not in processed_events:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/web3scout/event/sync_event.py:27, in SyncEvent.record(self, event, abi_load)
#      25     event_record = self._uni_v2_record(event, abi_load)
#      26 case JSONContracts.UniswapV2Pair:
# ---> 27     event_record = self._uni_v2_record(event, abi_load)
#      28 case JSONContracts.UniswapV3Pool:
#      29     event_record = self._uni_v3_record(event, abi_load)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/web3scout/event/sync_event.py:43, in SyncEvent._uni_v2_record(self, event, abi_load)
#      40 platform_nm = abi_load.get_platform_name()
#      42 w3 = self.__connect_w3.get_w3()
# ---> 43 pair: PairDetails = FetchPairDetails().apply(w3, event['address'])
#      45 amt0 = Conversion().convert_int256_bytes_to_int(arguments[0])
#      46 amt1 = Conversion().convert_int256_bytes_to_int(arguments[1])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/web3scout/uniswap_v2/fetch_pair_details.py:47, in FetchPairDetails.apply(self, web3, pair_contact_address, reverse_token_order, base_token_address, quote_token_address)
#      44     assert reverse_token_order is None, f"Give either (base_token_address, quote_token_address) or reverse_token_order"
#      45     reverse_token_order = int(base_token_address, 16) > int(quote_token_address, 16)
# ---> 47 pool = ABILoading().get_deployed_contract(web3, "sushi/UniswapV2Pair.json", pair_contact_address)
#      48 token0_address = pool.functions.token0().call()
#      49 token1_address = pool.functions.token1().call()
#
# NameError: name 'ABILoading' is not defined

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events

# %% [markdown]
# ### (5) Extract Transfer Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 5

# %%
dict_events = rEvents.apply(EventType.TRANSFER, start_block=start_block, end_block=last_block)

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
