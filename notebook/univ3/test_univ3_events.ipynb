# %%
import json
import time
from web3scout import *

# %%
abi = ABILoad(Platform.UNIV3, JSONContract.UniswapV3Pool)

# %% [markdown]
# ### (1) Extract Mint Events

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 15

# %%
dict_events = rEvents.apply(EventType.MINT, start_block=start_block, end_block=last_block)
# Out:
# mint at block:61,738,966 tx:0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458c4180cf910ac91d0bda7
# mint at block:61,738,966 tx:0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458c4180cf910ac91d0bda7
# mint at block:61,738,969 tx:0x3b32f84e3cb58f3e53f3bbc792fa27a3b901925bdc7f04ab0cf0535456bf77cc
# mint at block:61,738,970 tx:0x838c0c2bba9f45afbf18de702b1deb0b7f06bd3281ba197dc3eb1e4cd4171b3b
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#      chain       contract  type    platform  \
# 0  polygon  uniswapv3pool  mint  uniswap_v3
# 1  polygon  uniswapv3pool  mint  uniswap_v3
# 2  polygon  uniswapv3pool  mint  uniswap_v3
# 3  polygon  uniswapv3pool  mint  uniswap_v3
#
#                                  pool_address  \
# 0  0x50eaedb835021e4a108b7290636d62e9765cc6d7
# 1  0x50eaedb835021e4a108b7290636d62e9765cc6d7
# 2  0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9
# 3  0x5b41eedcfc8e0ae47493d4945aa1ae4fe05430ff
#
#                                              tx_hash   blk_num   timestamp  \
# 0  0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458...  61738966  1726154344
# 1  0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458...  61738966  1726154344
# 2  0x3b32f84e3cb58f3e53f3bbc792fa27a3b901925bdc7f...  61738969  1726154350
# 3  0x838c0c2bba9f45afbf18de702b1deb0b7f06bd3281ba...  61738970  1726154352
#
#                                              details
# 0  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 1  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 2  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 3  {'web3_type': <class 'web3._utils.datatypes.Mi...

# %% [markdown]
# ### (2) Extract Swap Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 3

# %%
dict_events = rEvents.apply(EventType.SWAP, start_block=start_block, end_block=last_block)
# Out:
# swap at block:61,738,977 tx:0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5c681ab7c6f810e83d802
# swap at block:61,738,977 tx:0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5c681ab7c6f810e83d802
# swap at block:61,738,977 tx:0x47bb8252168fe1d4295f2f3d48c67be04ff757d931e8fe46917765b0d41ed4ae
# swap at block:61,738,977 tx:0xcc68b613b723e79e3be4fe6d3eab5881090cf23e603876b34a0b45adc67d15ee
# swap at block:61,738,977 tx:0xcc68b613b723e79e3be4fe6d3eab5881090cf23e603876b34a0b45adc67d15ee
# swap at block:61,738,977 tx:0x92d0b97e09fedb7e253b961ce1ab6da261169f130ec6aaed34b0292b3246b043
# swap at block:61,738,978 tx:0x4f99ef2291d3b44cf01cf01f4e3c2cc8a254d34af1d9fbfa509472df7bc7f56c
# swap at block:61,738,978 tx:0x52a46bbc55a65701e43c7ae230027fcd12c35544856d4fd0e510c2cf002a14be
# swap at block:61,738,978 tx:0xeddfefb6cd245160a142cfc1e18c53f78db7fa886995409080cde2c55e4f6a4e
# swap at block:61,738,979 tx:0xfa44e7a45233d0581260c9f139ed2bc255f0f9c727f4bd36b19b3afb10805041
# swap at block:61,738,979 tx:0x75b00dfac78f23ddc3e4207818b4f8c6fb3f049a7fe08fc53bc623880408b7fb
# swap at block:61,738,979 tx:0x98f9c61e040dde1dc3acd42f8c74aeb049935c28a4a92c7b148091fb79a21e82
# swap at block:61,738,980 tx:0xb3cfdbbab3a65ed1cc82c15847dd4ad806a00878ffc6716a5fce617c9c6f947c
# swap at block:61,738,980 tx:0x98aa3d3865df4d539f798dc13b2d6ef187059de17c36f5032da34e2639e74a3f
# swap at block:61,738,980 tx:0x34848b5b4428d280d2fa386adf14e9b4edc8b2013d52c81dca676df37ade103f
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type    platform  \
# 0   polygon  uniswapv3pool  swap  uniswap_v3
# 1   polygon  uniswapv3pool  swap  uniswap_v3
# 2   polygon  uniswapv3pool  swap  uniswap_v3
# 3   polygon  uniswapv3pool  swap  uniswap_v3
# 4   polygon  uniswapv3pool  swap  uniswap_v3
# 5   polygon  uniswapv3pool  swap  uniswap_v3
# 6   polygon  uniswapv3pool  swap  uniswap_v3
# 7   polygon  uniswapv3pool  swap  uniswap_v3
# 8   polygon  uniswapv3pool  swap  uniswap_v3
# 9   polygon  uniswapv3pool  swap  uniswap_v3
# 10  polygon  uniswapv3pool  swap  uniswap_v3
# 11  polygon  uniswapv3pool  swap  uniswap_v3
# 12  polygon  uniswapv3pool  swap  uniswap_v3
# 13  polygon  uniswapv3pool  swap  uniswap_v3
# 14  polygon  uniswapv3pool  swap  uniswap_v3
#
#                                        address  \
# 0   0x0e3eb2c75bd7dd0e12249d96b1321d9570764d77
# 1   0xa6aedf7c4ed6e821e67a6bfd56fd1702ad9a9719
# 2   0x44720a6f572649526ac9073cae9200755cc78e0a
# 3   0x479e1b71a702a595e19b6d5932cd5c863ab57ee0
# 4   0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d
# 5   0xeef1a9507b3d505f0062f2be9453981255b503c8
# 6   0x420253cab257fb9c8042df669c410c4b06778469
# 7   0xb6e57ed85c4c9dbfef2a68711e9d6f36c56e0fcb
# 8   0x20fb28b6209ed80eee40894baa9a199c07b03e55
# 9   0xd36ec33c8bed5a9f7b6630855f1533455b98a418
# 10  0x60ea32a35f64628328f578c872dd6c6d81626aba
# 11  0x32fae204835e08b9374493d6b4628fd1f87dd045
# 12  0x44720a6f572649526ac9073cae9200755cc78e0a
# 13  0x6e33c0f5e16b45114679eac217e0c0138cefcd2e
# 14  0x6e33c0f5e16b45114679eac217e0c0138cefcd2e
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5...  61738977  1726154368
# 1   0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5...  61738977  1726154368
# 2   0x47bb8252168fe1d4295f2f3d48c67be04ff757d931e8...  61738977  1726154368
# 3   0xcc68b613b723e79e3be4fe6d3eab5881090cf23e6038...  61738977  1726154368
# 4   0xcc68b613b723e79e3be4fe6d3eab5881090cf23e6038...  61738977  1726154368
# 5   0x92d0b97e09fedb7e253b961ce1ab6da261169f130ec6...  61738977  1726154368
# 6   0x4f99ef2291d3b44cf01cf01f4e3c2cc8a254d34af1d9...  61738978  1726154370
# 7   0x52a46bbc55a65701e43c7ae230027fcd12c35544856d...  61738978  1726154370
# 8   0xeddfefb6cd245160a142cfc1e18c53f78db7fa886995...  61738978  1726154370
# 9   0xfa44e7a45233d0581260c9f139ed2bc255f0f9c727f4...  61738979  1726154372
# 10  0x75b00dfac78f23ddc3e4207818b4f8c6fb3f049a7fe0...  61738979  1726154372
# 11  0x98f9c61e040dde1dc3acd42f8c74aeb049935c28a4a9...  61738979  1726154372
# 12  0xb3cfdbbab3a65ed1cc82c15847dd4ad806a00878ffc6...  61738980  1726154374
# 13  0x98aa3d3865df4d539f798dc13b2d6ef187059de17c36...  61738980  1726154374
# 14  0x34848b5b4428d280d2fa386adf14e9b4edc8b2013d52...  61738980  1726154374
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 1   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 2   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 3   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 4   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 5   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 6   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 7   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 8   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 9   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 10  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 11  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 12  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 13  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 14  {'web3_type': <class 'web3._utils.datatypes.Sw...

# %%
dict_events
# Out:
# {0: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x0e3eb2c75bd7dd0e12249d96b1321d9570764d77',
#   'tx_hash': '0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5c681ab7c6f810e83d802',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa8376f53391a041C8236A232f7f019EA76eEd86d',
#    'token1': '0xa8376f53391a041C8236A232f7f019EA76eEd86d',
#    'amount0': -100112070,
#    'amount1': 100112600,
#    'sqrt_price_x96': 79228014110034608645545317301,
#    'liquidity': 102674703543637,
#    'tick': -1}},
#  1: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xa6aedf7c4ed6e821e67a6bfd56fd1702ad9a9719',
#   'tx_hash': '0x0b61eef06ae9bc570c91721181b677fdbf856ba488b5c681ab7c6f810e83d802',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xa8376f53391a041C8236A232f7f019EA76eEd86d',
#    'token1': '0x4E3288c9ca110bCC82bf38F09A7b425c095d92Bf',
#    'amount0': 100112070,
#    'amount1': -42956567858648645,
#    'sqrt_price_x96': 1641535209159311096472102367305625,
#    'liquidity': 297972974576391922,
#    'tick': 198786}},
#  2: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x44720a6f572649526ac9073cae9200755cc78e0a',
#   'tx_hash': '0x47bb8252168fe1d4295f2f3d48c67be04ff757d931e8fe46917765b0d41ed4ae',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xf5b509bB0909a69B1c207E495f687a596C168E12',
#    'token1': '0xC3610e92b94f3A897c1954C7Ea4e4aD06B3c6D4a',
#    'amount0': 50567143641384016,
#    'amount1': -807904260298655843,
#    'sqrt_price_x96': 316901083815943224027773473639,
#    'liquidity': 1286618357249578990730,
#    'tick': 27726}},
#  3: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x479e1b71a702a595e19b6d5932cd5c863ab57ee0',
#   'tx_hash': '0xcc68b613b723e79e3be4fe6d3eab5881090cf23e603876b34a0b45adc67d15ee',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xf5b509bB0909a69B1c207E495f687a596C168E12',
#    'token1': '0xd951Ec6f1D1746d1DeB87210C75E0071FB99a956',
#    'amount0': -3146719971483988667184,
#    'amount1': 506467952262303104,
#    'sqrt_price_x96': 1004923994993640535717235633,
#    'liquidity': 3496303237545074831839853,
#    'tick': -87353}},
#  4: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d',
#   'tx_hash': '0xcc68b613b723e79e3be4fe6d3eab5881090cf23e603876b34a0b45adc67d15ee',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xf5b509bB0909a69B1c207E495f687a596C168E12',
#    'token1': '0xd951Ec6f1D1746d1DeB87210C75E0071FB99a956',
#    'amount0': 3146719971477985165312,
#    'amount1': -1180157217,
#    'sqrt_price_x96': 48527319427013822050492,
#    'liquidity': 16202103803078675312,
#    'tick': -286129}},
#  5: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xeef1a9507b3d505f0062f2be9453981255b503c8',
#   'tx_hash': '0x92d0b97e09fedb7e253b961ce1ab6da261169f130ec6aaed34b0292b3246b043',
#   'blk_num': 61738977,
#   'timestamp': 1726154368,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': -468962,
#    'amount1': 270622594,
#    'sqrt_price_x96': 1902770754456005028799677204428,
#    'liquidity': 1023094094823,
#    'tick': 63577}},
#  6: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x420253cab257fb9c8042df669c410c4b06778469',
#   'tx_hash': '0x4f99ef2291d3b44cf01cf01f4e3c2cc8a254d34af1d9fbfa509472df7bc7f56c',
#   'blk_num': 61738978,
#   'timestamp': 1726154370,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#    'token1': '0xd047fd23de6f014a8470a1EfdA9830d071488835',
#    'amount0': 10459443686316294799360,
#    'amount1': -75054,
#    'sqrt_price_x96': 212541012032815318021,
#    'liquidity': 247280524827600346,
#    'tick': -394749}},
#  7: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xb6e57ed85c4c9dbfef2a68711e9d6f36c56e0fcb',
#   'tx_hash': '0x52a46bbc55a65701e43c7ae230027fcd12c35544856d4fd0e510c2cf002a14be',
#   'blk_num': 61738978,
#   'timestamp': 1726154370,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xe9d1d72f1D05098f7Aeb0C768f44CF46c63235ec',
#    'token1': '0xe9d1d72f1D05098f7Aeb0C768f44CF46c63235ec',
#    'amount0': -1946236025711005279,
#    'amount1': 730513,
#    'sqrt_price_x96': 48527388707727710239038,
#    'liquidity': 3113547267331667173,
#    'tick': -286129}},
#  8: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x20fb28b6209ed80eee40894baa9a199c07b03e55',
#   'tx_hash': '0xeddfefb6cd245160a142cfc1e18c53f78db7fa886995409080cde2c55e4f6a4e',
#   'blk_num': 61738978,
#   'timestamp': 1726154370,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xe9d1d72f1D05098f7Aeb0C768f44CF46c63235ec',
#    'token1': '0x3c93FBb420Ef2E66308CB345D22d63c828549A4d',
#    'amount0': 60603,
#    'amount1': -413042222574312,
#    'sqrt_price_x96': 6550625066378239788584704840836609,
#    'liquidity': 9764030618199797,
#    'tick': 226466}},
#  9: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xd36ec33c8bed5a9f7b6630855f1533455b98a418',
#   'tx_hash': '0xfa44e7a45233d0581260c9f139ed2bc255f0f9c727f4bd36b19b3afb10805041',
#   'blk_num': 61738979,
#   'timestamp': 1726154372,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#    'token1': '0xdB6f1920A889355780aF7570773609Bd8Cb1f498',
#    'amount0': -1999679,
#    'amount1': 2000000,
#    'sqrt_price_x96': 79230551914094846877330972762,
#    'liquidity': 47219520645724384,
#    'tick': 0}},
#  10: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x60ea32a35f64628328f578c872dd6c6d81626aba',
#   'tx_hash': '0x75b00dfac78f23ddc3e4207818b4f8c6fb3f049a7fe08fc53bc623880408b7fb',
#   'blk_num': 61738979,
#   'timestamp': 1726154372,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45',
#    'token1': '0xC89277c6FFbE1CC6e40d61bD114904A8EaFaF382',
#    'amount0': -14391854423933680213,
#    'amount1': 17643000,
#    'sqrt_price_x96': 87592077799236071734388,
#    'liquidity': 351572515821361153,
#    'tick': -274317}},
#  11: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x32fae204835e08b9374493d6b4628fd1f87dd045',
#   'tx_hash': '0x98f9c61e040dde1dc3acd42f8c74aeb049935c28a4a92c7b148091fb79a21e82',
#   'blk_num': 61738979,
#   'timestamp': 1726154372,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': -154320,
#    'amount1': 89068187,
#    'sqrt_price_x96': 1902961524642967835809812322342,
#    'liquidity': 79349222993,
#    'tick': 63579}},
#  12: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x44720a6f572649526ac9073cae9200755cc78e0a',
#   'tx_hash': '0xb3cfdbbab3a65ed1cc82c15847dd4ad806a00878ffc6716a5fce617c9c6f947c',
#   'blk_num': 61738980,
#   'timestamp': 1726154374,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xf5b509bB0909a69B1c207E495f687a596C168E12',
#    'token1': '0x8B26320912935111300DdAeeC15EA9a182FF6F1a',
#    'amount0': 80109984048718176,
#    'amount1': -1279387097601004730,
#    'sqrt_price_x96': 316822300944304371122107862701,
#    'liquidity': 1286618357249578990730,
#    'tick': 27721}},
#  13: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x6e33c0f5e16b45114679eac217e0c0138cefcd2e',
#   'tx_hash': '0x98aa3d3865df4d539f798dc13b2d6ef187059de17c36f5032da34e2639e74a3f',
#   'blk_num': 61738980,
#   'timestamp': 1726154374,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#    'token1': '0x342540764D1Eb143789F0aC908f75A7C5380762d',
#    'amount0': -217046974672104442592,
#    'amount1': 42418950322733553130043,
#    'sqrt_price_x96': 1105939911860699518035540991928,
#    'liquidity': 514715082049184448158082137,
#    'tick': 52725}},
#  14: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x6e33c0f5e16b45114679eac217e0c0138cefcd2e',
#   'tx_hash': '0x34848b5b4428d280d2fa386adf14e9b4edc8b2013d52c81dca676df37ade103f',
#   'blk_num': 61738980,
#   'timestamp': 1726154374,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#    'token1': '0x342540764D1Eb143789F0aC908f75A7C5380762d',
#    'amount0': -122087800378904179436,
#    'amount1': 23860659556537623635649,
#    'sqrt_price_x96': 1105943573624207399210813431110,
#    'liquidity': 514715082049184448158082137,
#    'tick': 52725}}}

# %% [markdown]
# ### (3) Extract Burn Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 250

# %%
dict_events = rEvents.apply(EventType.BURN, start_block=start_block, end_block=last_block)
# Out:
# burn at block:61,738,730 tx:0x90af9fb6964bd0951e7bbdd8d8c3aa63913df2bfa344a817be4b1af4b1e3ea01
# burn at block:61,738,731 tx:0x435b09d7c8a149c65bcd593e9c0cdf0eff2a32c0dfadd5cb2ce476b67d26596e
# burn at block:61,738,731 tx:0x435b09d7c8a149c65bcd593e9c0cdf0eff2a32c0dfadd5cb2ce476b67d26596e
# burn at block:61,738,733 tx:0x9713b6e1ceb5031bd64389e794d0f6361fd1f9699f9ffcaca5515d8040decdba
# burn at block:61,738,734 tx:0xbdf59d30465b19285bcbcb96ecbea6712a841e716b8df249fd37f406154e6975
# burn at block:61,738,737 tx:0xf76aad7b0a6dd1cd1b113a1ed0dad9b664de25be371cd4e89e219dd1b5533b33
# burn at block:61,738,743 tx:0xfd0c2330d7073e36c931522990cc0fecbb29b23199e5860a4e404c8f832224fc
# burn at block:61,738,743 tx:0xfd0c2330d7073e36c931522990cc0fecbb29b23199e5860a4e404c8f832224fc
# burn at block:61,738,756 tx:0xa8ca5d73baaf3bc38898036dbc161f9b448dc3a1aba709b6861e59b185297265
# burn at block:61,738,756 tx:0xa8ca5d73baaf3bc38898036dbc161f9b448dc3a1aba709b6861e59b185297265
# burn at block:61,738,766 tx:0x0d0dab6257ba5cb2e5366a5e6bd81f199008440a374f47d747ea4ddf89cf986f
# burn at block:61,738,769 tx:0xac19357a219b49f95857966f1c13a720a7d0f9022fbec63c5be1e57eb99310bf
# burn at block:61,738,771 tx:0xd3f32771220da947f4e1ec67948206615d9ba14d79742de0be76d0d07f32566d
# burn at block:61,738,777 tx:0xe2aa1c6a4abfd288dee501ebae3e483c9b6aef9c49f239e752beee7256e9405a
# burn at block:61,738,902 tx:0xda248b345fa138b197f93dc2ec0b6a0964fffb6bd951124726ed499c233102f8
# burn at block:61,738,905 tx:0xca65548b14fc4e030df8d9f6a18582d28d9ecc89b8b6477c2fe6d8627ea3c1ae
# burn at block:61,738,916 tx:0x10ae2f125a56d87ca90ae189f7299a654f897c51e026fb5043c1313eef299e14
# burn at block:61,738,921 tx:0xd18ce4a3f18a34d350615f91a84b560d4857798f2016f982edc296a37e3e4312
# burn at block:61,738,923 tx:0xcf3bc7a78dff852314a3ba3c2ae9ce65a71a5b597d70cb2b5789e1cac517d536
# burn at block:61,738,923 tx:0xcf3bc7a78dff852314a3ba3c2ae9ce65a71a5b597d70cb2b5789e1cac517d536
# burn at block:61,738,929 tx:0x393f9c9e83ab069f3002fca860d014e7fd951c17a9d64e8ae3513a4caf66778f
# burn at block:61,738,929 tx:0x393f9c9e83ab069f3002fca860d014e7fd951c17a9d64e8ae3513a4caf66778f
# burn at block:61,738,944 tx:0x74e156335ed3d501b4725036953f0419742fd2701dd56b2c2c925f29eaa5d666
# burn at block:61,738,949 tx:0xe2bf139852d72a87c7e150446b095345f97963936c8db98d51436329df41bfb8
# burn at block:61,738,955 tx:0xad983c2fdc7bbec65a334a85a27648413f038a61ae5d2310658ee80298385750
# burn at block:61,738,955 tx:0x92207ad3ee368c5859ade392f83e15037e4a7b7f389af7e6227ef386dee9ce8d
# burn at block:61,738,958 tx:0x9a5c4982814e69c8d897e9b7f04096d7e0d28b376f26d7f0fab90c0a5953110f
# burn at block:61,738,966 tx:0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458c4180cf910ac91d0bda7
# burn at block:61,738,966 tx:0x4a4322a8b7dcf1686e8818ff3d18bfef1e99b06b1458c4180cf910ac91d0bda7
# burn at block:61,738,967 tx:0x15f6dc2f31f0f936374e7a7d20cb08abb05a4922a46af7d00cb0eb2dea11e5cf
# burn at block:61,738,970 tx:0x838c0c2bba9f45afbf18de702b1deb0b7f06bd3281ba197dc3eb1e4cd4171b3b
# burn at block:61,738,970 tx:0x838c0c2bba9f45afbf18de702b1deb0b7f06bd3281ba197dc3eb1e4cd4171b3b
# burn at block:61,738,978 tx:0xe9fa08f6323cd7bcefaf58b3a154e5b2bf56afbd89c6bbf0daf4182ee27c2b5d
# burn at block:61,738,978 tx:0xe9fa08f6323cd7bcefaf58b3a154e5b2bf56afbd89c6bbf0daf4182ee27c2b5d
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type    platform  \
# 0   polygon  uniswapv3pool  burn  uniswap_v3
# 1   polygon  uniswapv3pool  burn  uniswap_v3
# 2   polygon  uniswapv3pool  burn  uniswap_v3
# 3   polygon  uniswapv3pool  burn  uniswap_v3
# 4   polygon  uniswapv3pool  burn  uniswap_v3
# 5   polygon  uniswapv3pool  burn  uniswap_v3
# 6   polygon  uniswapv3pool  burn  uniswap_v3
# 7   polygon  uniswapv3pool  burn  uniswap_v3
# 8   polygon  uniswapv3pool  burn  uniswap_v3
# 9   polygon  uniswapv3pool  burn  uniswap_v3
# 10  polygon  uniswapv3pool  burn  uniswap_v3
# 11  polygon  uniswapv3pool  burn  uniswap_v3
# 12  polygon  uniswapv3pool  burn  uniswap_v3
# 13  polygon  uniswapv3pool  burn  uniswap_v3
# 14  polygon  uniswapv3pool  burn  uniswap_v3
# 15  polygon  uniswapv3pool  burn  uniswap_v3
# 16  polygon  uniswapv3pool  burn  uniswap_v3
# 17  polygon  uniswapv3pool  burn  uniswap_v3
# 18  polygon  uniswapv3pool  burn  uniswap_v3
# 19  polygon  uniswapv3pool  burn  uniswap_v3
# 20  polygon  uniswapv3pool  burn  uniswap_v3
# 21  polygon  uniswapv3pool  burn  uniswap_v3
# 22  polygon  uniswapv3pool  burn  uniswap_v3
# 23  polygon  uniswapv3pool  burn  uniswap_v3
# 24  polygon  uniswapv3pool  burn  uniswap_v3
# 25  polygon  uniswapv3pool  burn  uniswap_v3
# 26  polygon  uniswapv3pool  burn  uniswap_v3
# 27  polygon  uniswapv3pool  burn  uniswap_v3
# 28  polygon  uniswapv3pool  burn  uniswap_v3
# 29  polygon  uniswapv3pool  burn  uniswap_v3
# 30  polygon  uniswapv3pool  burn  uniswap_v3
# 31  polygon  uniswapv3pool  burn  uniswap_v3
# 32  polygon  uniswapv3pool  burn  uniswap_v3
# 33  polygon  uniswapv3pool  burn  uniswap_v3
# 34  polygon  uniswapv3pool  burn  uniswap_v3
# 35  polygon  uniswapv3pool  burn  uniswap_v3
# 36  polygon  uniswapv3pool  burn  uniswap_v3
# 37  polygon  uniswapv3pool  burn  uniswap_v3
# 38  polygon  uniswapv3pool  burn  uniswap_v3
# 39  polygon  uniswapv3pool  burn  uniswap_v3
# 40  polygon  uniswapv3pool  burn  uniswap_v3
# 41  polygon  uniswapv3pool  burn  uniswap_v3
# 42  polygon  uniswapv3pool  burn  uniswap_v3
# 43  polygon  uniswapv3pool  burn  uniswap_v3
# 44  polygon  uniswapv3pool  burn  uniswap_v3
# 45  polygon  uniswapv3pool  burn  uniswap_v3
# 46  polygon  uniswapv3pool  burn  uniswap_v3
# 47  polygon  uniswapv3pool  burn  uniswap_v3
# 48  polygon  uniswapv3pool  burn  uniswap_v3
# 49  polygon  uniswapv3pool  burn  uniswap_v3
# 50  polygon  uniswapv3pool  burn  uniswap_v3
# 51  polygon  uniswapv3pool  burn  uniswap_v3
# 52  polygon  uniswapv3pool  burn  uniswap_v3
# 53  polygon  uniswapv3pool  burn  uniswap_v3
# 54  polygon  uniswapv3pool  burn  uniswap_v3
# 55  polygon  uniswapv3pool  burn  uniswap_v3
# 56  polygon  uniswapv3pool  burn  uniswap_v3
# 57  polygon  uniswapv3pool  burn  uniswap_v3
# 58  polygon  uniswapv3pool  burn  uniswap_v3
# 59  polygon  uniswapv3pool  burn  uniswap_v3
#
#                                        address  \
# 0   0x167384319b41f7094e62f7506409eb38079abff8
# 1   0x9ceff2f5138fc59eb925d270b8a7a9c02a1810f2
# 2   0x9ceff2f5138fc59eb925d270b8a7a9c02a1810f2
# 3   0x3e31ab7f37c048fc6574189135d108df80f0ea26
# 4   0x65906dbdfca73c67cf35744864d2f3f9f71a8c44
# 0   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 1   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 2   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 3   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 4   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 5   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 6   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 7   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 8   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 9   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 10  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 11  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 12  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 13  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 14  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 15  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 16  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 17  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 18  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 19  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 20  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 21  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 22  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 23  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 24  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 25  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 26  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 27  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 28  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 29  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 30  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 31  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 32  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 33  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 34  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 35  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 36  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 37  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 38  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 39  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 40  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 41  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 42  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 43  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 44  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 45  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 46  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 47  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 48  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 49  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 50  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 51  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 52  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 53  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 54  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 55  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 56  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 57  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 58  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 59  {'web3_type': <class 'web3._utils.datatypes.Bu...

# %% [markdown]
# ### (4) Create Events

# %%
time.sleep(2)

# %%
abi = ABILoad(Platform.UNIV3, JSONContract.UniswapV3Factory)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 5000

# %%
dict_events = rEvents.apply(EventType.CREATE, start_block=start_block, end_block=last_block)
# Out:
# create at block:61,737,362 tx:0x63b507e76948faffe2a8c4a044aefeba9df3c0a62ee1a152850d3a8957ddc5f8
# create at block:61,738,038 tx:0x59a6e8c13807c575b8aec8d08b9944decef51e57a066849df01856d34424fe41
# create at block:61,738,093 tx:0x6ef75b6b524eff8dd4efd9e1cc239e41c45a960c93a4187628c33ee80d6294c8
# create at block:61,738,146 tx:0x04a63b88ed61a74d957eead92d7fc53fac0697f5e76029949b199e31c4c1e878
# create at block:61,738,915 tx:0x0f8ea0cac412ab8ff8ce039b5603044538299777af41b642c42e76f291b92c93
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#      chain          contract         type    platform  \
# 0  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 1  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 2  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 3  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 4  polygon  uniswapv3factory  poolcreated  uniswap_v3
#
#                                       address  \
# 0  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 1  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 2  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 3  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 4  0x1f98431c8ad98523631ae4a59f267346ea31f984
#
#                                              tx_hash   blk_num   timestamp  \
# 0  0x63b507e76948faffe2a8c4a044aefeba9df3c0a62ee1...  61737362  1726150935
# 1  0x59a6e8c13807c575b8aec8d08b9944decef51e57a066...  61738038  1726152371
# 2  0x6ef75b6b524eff8dd4efd9e1cc239e41c45a960c93a4...  61738093  1726152487
# 3  0x04a63b88ed61a74d957eead92d7fc53fac0697f5e760...  61738146  1726152601
# 4  0x0f8ea0cac412ab8ff8ce039b5603044538299777af41...  61738915  1726154235
#
#                                              details
# 0  {'web3_type': <class 'web3._utils.datatypes.Po...
# 1  {'web3_type': <class 'web3._utils.datatypes.Po...
# 2  {'web3_type': <class 'web3._utils.datatypes.Po...
# 3  {'web3_type': <class 'web3._utils.datatypes.Po...
# 4  {'web3_type': <class 'web3._utils.datatypes.Po...
